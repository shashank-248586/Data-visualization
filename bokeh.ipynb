# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
from bokeh.plotting import figure, output_file, show
import numpy as np
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f55b8e36-7c58-4f7c-9b78-5ee7585af175">Loading BokehJS ...</span>
#     </div>

# %%
x=[i for i in range(1,11)]
output_file('test.html')
p=figure()
p.circle(x,np.sin(x),size=20)
show(p)
# Out:
#   <div id="f9280ea5-6111-44ba-bb2b-42153ed4f1c8" data-root-id="p1001" style="display: contents;"></div>

# %%
x=np.random.choice(['red','blue','green','yellow'],20)
y=np.random.random(20)
z=np.array([i for i in range(1,21)])
p = figure()
for i in range(20):
    p.scatter(y,z,size=10*y[i],color=x[i])
show(p)
# Out:
#   <div id="f4e1f17c-ce3a-4f4a-91a7-6c8eef651490" data-root-id="p1045" style="display: contents;"></div>

# %%
fruits = ['Apples', 'Oranges', 'Bananas', 'Pears']
counts = [20, 25, 30, 35]
p = figure(x_range=fruits, height=350, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
# Out:
#   <div id="d49183b3-fb68-426d-92db-244c0701d3db" data-root-id="p1464" style="display: contents;"></div>

# %%
data_hist = np.random.randn(1000)
hist, edges = np.histogram(data_hist, bins=30)
bins=edges
# Out:
# array([-4.12539999, -3.87149015, -3.61758031, -3.36367047, -3.10976063,
#        -2.8558508 , -2.60194096, -2.34803112, -2.09412128, -1.84021144,
#        -1.5863016 , -1.33239176, -1.07848192, -0.82457208, -0.57066224,
#        -0.3167524 , -0.06284256,  0.19106727,  0.44497711,  0.69888695,
#         0.95279679,  1.20670663,  1.46061647,  1.71452631,  1.96843615,
#         2.22234599,  2.47625583,  2.73016567,  2.98407551,  3.23798534,
#         3.49189518])

# %%
import numpy as np

from bokeh.plotting import figure, show

rng = np.random.default_rng()
x = hist

p = figure(width=670, height=400, toolbar_location=None,
           title="Normal (Gaussian) Distribution")
p.quad(top=x,bottom=0,left=edges[:-1],right=edges[1:],fill_color='blue',line_color='red')
p.y_range.start = 0
p.xaxis.axis_label = "hist"
p.yaxis.axis_label = "edges"

show(p)
# Out:
#   <div id="ae6d89ff-de55-42b1-8437-bc6b91e9ca2a" data-root-id="p1531" style="display: contents;"></div>

# %%
data_heatmap = np.random.rand(10, 10)
x = np.linspace(0, 1, 10)
y = np.linspace(0, 1, 10)
xx, yy = np.meshgrid(x, y)
data_heatmap
# Out:
# array([[0.10154728, 0.48458161, 0.40508869, 0.45614182, 0.2838328 ,
#         0.45964445, 0.40561746, 0.27261659, 0.52329703, 0.26897811],
#        [0.27147508, 0.29260341, 0.85049394, 0.3745808 , 0.02754572,
#         0.35988501, 0.60409343, 0.80254454, 0.73997015, 0.86407346],
#        [0.38250608, 0.24122164, 0.58732703, 0.69557392, 0.68367232,
#         0.2350963 , 0.04962541, 0.51022322, 0.45974828, 0.30230123],
#        [0.31018795, 0.06014995, 0.18351091, 0.22282934, 0.52279558,
#         0.57779113, 0.94464572, 0.69404001, 0.24387766, 0.25091985],
#        [0.59273756, 0.50365885, 0.09081272, 0.7916073 , 0.44103091,
#         0.32903795, 0.60130582, 0.08112887, 0.26964752, 0.43824579],
#        [0.43047756, 0.09186284, 0.36646834, 0.01219764, 0.75674339,
#         0.96350878, 0.35668569, 0.50292548, 0.11277834, 0.35344082],
#        [0.7745348 , 0.8244352 , 0.41166333, 0.74989891, 0.2584887 ,
#         0.23534004, 0.20184677, 0.83784451, 0.89571425, 0.21538751],
# ...

# %%
p=figure(tools='hover')
p.rect(x,y,width=1, height=1)
show(p)
# Out:
#   <div id="c6dda3cb-7886-483d-b237-104729536ba2" data-root-id="p1750" style="display: contents;"></div>
